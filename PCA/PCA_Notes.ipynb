# %% [markdown]
# <a href="https://colab.research.google.com/github/ramrajv/Upgrad_Pt_2/blob/main/PCA/PCA_Notes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
A = np.array([[2,1,1],[3,2,1],[2,1,2]])
B = np.linalg.inv(A)

# %%
B
# Out:
# array([[ 3., -1., -1.],
#        [-4.,  2.,  1.],
#        [-1.,  0.,  1.]])

# %%
A @ B
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %% [markdown]
# # 22 Mar 22
#
# ## Finding basis vectors
#
# The fundamental equation to move between different basis vectors that we studied in the previous session is shown as follows:
#
# Our target was to represent M in the terms of the old basis vectors and the new basis vectors.
#
#
# Before we move to that part, we need to set some conventions for ease of use. These conventions are given as follows:
#
# B1 will represent the old basis and v1 is the old basis representation
# B2 will represent the new basis and v2 is the new basis representation
# This would mean that the equation shown just previously can be written as:
#
# $v_{2} = M∗v_{1}$
#
# Let's consider this as equation 1.
#
# Now, when we shift between multiple basis vectors the following equation remains valid,
#
# $B_{1} ∗ v_{1} = B_{2} ∗ v_{2}$
#
# A slight manipulation of this equation gives us the following equation:
#
# $B_{2}^{-1}*B_{1} * v_{1} = B_{2}^{-1}*B_{2} * v_{2}$
#
# which gets converted to:
#
# $v_{2}=B_{2}^{-1}*B_{1} * v_{1}$ since $B_{2}^{-1}*B_{2}$ is unity.
#
# Let's consider this as equation 2.
#
# On comparing Equation 1 and  2, we get the following equation for M as follows:
#
# $M = B_{2}^{-1}B_{1}$

# %% [markdown]
# The following image summarises the learnings of the video above (click on the image to enlarge it)
# ![Representation between multiple basis vectors.jpg](data:image/jpeg;base64,...)
#
#
#
#
#
#
# Mainly when we're moving between multiple basis vectors, it's important to know that the point's position in space doesn't change. The point's representation might be different in different basis vectors but it would be representing the same point.

# %% [markdown]
# There are 3 major steps that need to be performed while doing change of basis operations in python. After you've set the proper conventions for moving from B1 to B2, you need to
#
#
#
# - Store the basis vector matrices in numpy arrays. Make sure that you're passing the rows of the basis vector matrix as arguments while creating the matrices.
#
#
#
# - Create the transformation matrix by using the formula mentioned below:
#
# >>>$M = B_{2}^{-1}B_{1}$
#
# - Finally, use the change of basis equation for finding a point's new representation from old representation,
#
# >>>$v_{2} = M * v_{1}$

# %% [markdown]
# ## Comprehension
#
# Let's say you have a point $ \left[\begin{array}-8\\6\end{array}\right]$ in the standard basis vectors in 2-d $ \left[\begin{array}-1\\0\end{array}\right]$ and $ \left[\begin{array}-0\\1\end{array}\right]$
#
# You want to find its representation in the following basis:
#
# $ \left[\begin{array}-2&-2\\1&1\end{array}\right]$

# %% [markdown]
# ### Question 1/4
# The correct set of conventions as per the problem statement are:
#
# #### Answer:
#
# $v_{1}$ = $ \left[\begin{array}-8\\6\end{array}\right]$
#
# $B_{1} =  \left[\begin{array}-1&0\\0&1\end{array}\right] $ and $B_{2} = \left[\begin{array}-2&-2\\1&1\end{array}\right]$

# %% [markdown]
# ### Question 2/4
# #### Storing Basis Vectors in Numpy arrays
# Let's say you want to store $B_{2} = \left[\begin{array}-2&-2\\1&1\end{array}\right]$ in a variable using numpy arrays. The correct syntax for this would be:
#
# ### Answer:
#     B2 = np.array([[2,-2],[1,1]])

# %% [markdown]
# ### Question 3/4
#
# Finding the matrix M
#
# What would be the matrix M in this scenario?
#
# ### Answer:
#
# $M = \left[\begin{array}-0.25&0.5\\-0.25&0.5\end{array}\right]$

# %% [markdown]
# ### Question 4/4
#
# #### Finding the new representation
# What is the representation of the point i.e. $\left[\begin{array}-8\\6\end{array}\right]$ in the new basis?
#
# ### Answer:

# %%
M = np.array([[0.25,0.5],[-0.25,0.5]])
v1 = np.array([[8],[6]])
v2 = M@v1

# %%
v2
# Out:
# array([[5.],
#        [1.]])

# %% [markdown]
# #### Feedback:
#
# We know that $v_{2}  = M*v_{1}$
#
# Now
#
# $v_{1} = \left[\begin{array}-8\\6\end{array}\right]$
#
# and
#
#
# $M = \left[\begin{array}-0.25&0.5\\-0.25&0.5\end{array}\right]$
#
# Substituting the values, we can ge the value of v2. In python, the code is as above.

# %% [markdown]
# # Comprehension:I
#
# Imagine you went to a different planet for exploratory reasons to find intelligent life there. You met an alien and you started showing it where you came from and location of Earth from that planet.
#
#
#
# You realised that the basis used by the alien is not the same as yours.
#
#
#
# You use the basis
#
# $B_{1} = \left[\begin{array}-1\\0\end{array}\right] and \left[\begin{array}-0\\1\end{array}\right]$
#
# while the alien uses the basis $B_{2} = \left[\begin{array}-1\\-2\end{array}\right] and \left[\begin{array}-1\\1\end{array}\right]$.
#
# Now answer the following questions.
#
# ### Question 1/2
#
# #### Position of Saturn
# You want to tell the new alien friend about the beautiful Saturn.
#
# The location of Saturn in your basis is $\left[\begin{array}-25\\28\end{array}\right]$.
#
# What is the representation of the same in Alien's basis?

# %%
# Get basis

B1 = np.array([[1,0],[0,1]])
B2 = np.array([[1,1],[-2,1]])
v1 = np.array([[25],[28]])

# v2 = B2 inverse * B1 * v1 where M is B2 inverse B1

M = np.linalg.inv(B2) @ B1
v2 = M @ v1

# %%
v2
# Out:
# array([[-1.],
#        [26.]])

# %%
M
# Out:
# array([[ 0.33333333, -0.33333333],
#        [ 0.66666667,  0.33333333]])

# %% [markdown]
# #### Feedback:
#
# We simply multiply by the matrix we found.
#
# $\left[\begin{array}-1&1\\-2&1\end{array}\right]^{-1}.\left[\begin{array}-25\\28\end{array}\right]$

# %% [markdown]
# ### Question 2/2
#
# Position of Kappa
# The Alien also tells you the location of a planet that also has intelligent life, Kappa. The position is however in Alien's basis. To make this information useful to Earth people you have to convert the position to Earth's Basis $B_{1}$
# . The representation of Kappa in Alien's basis is $\left[\begin{array}--3\\12\end{array}\right]$.
#
# What is the representation in your Basis?

# %%
# Representation in alien's basis is v2

v2 = np.array([[-3],[12]])

# We need to find representation in our basis, which is v1.
# v1 = M inverse v2 or B2v2 since B1 is identity matrix.

v1 = np.linalg.inv(M) @ v2

# %%
v1
# Out:
# array([[ 9.],
#        [18.]])

# %% [markdown]
# #### Feedback
#
# We saw, to get the representation we multiply by the matrix obtained by writing basis of Alien as column vectors.

# %%
v1 = B2 @ v2

# %%
v1
# Out:
# array([[ 9],
#        [18]])

# %% [markdown]
# $\left[\begin{array}-1&1\\-2&1\end{array}\right]\left[\begin{array}--3\\12\end{array}\right] = \left[\begin{array}-9\\18\end{array}\right]$.

# %% [markdown]
# # PCA and Change of Basis
#
# In the previous segments, you learnt the concept of basis and the change of basis. Now, you might wonder what role does it have to play in PCA. Let's understand how the change of basis plays an important role in the case of dimensionality reduction. Change in basis is done by the following way:
#
# >PCA finds new basis vectors for us. These new basis
# vectors are also known as Principal Components.
#
# >We represent the data using these new Principal Components by performing the change of basis calculations.
#
# >After doing the change of basis, we can perform dimensionality reduction. In fact, PCA finds new basis vectors in such a way that it becomes easier for us to discard a few of the features.

# %% [markdown]
# ## Calculations for the demonstration
#
# Here are the relevant calculations that were done to obtain the new dataset from the original dataset.
#
# We had the following dataset in the beginning.
#
#
#
#
# ---
# $Point\quad X \quad Y$
#
# ---
# $P1 \quad \quad 2 \quad 1$\
# $P1 \quad \quad 3 \quad 1.5$\
# $P1 \quad \quad 4 \quad 2$\
# $P1 \quad \quad 6 \quad 3$\
# $P1 \quad \quad 7 \quad 3.5$\
# $P1 \quad \quad 8 \quad 4$
#
# Figure below

# %%
import pandas as pd

X = np.array([2,3,4,6,7,8])
y = np.array([1,1.5,2,3,3.5,4])
df = pd.DataFrame(X,y)
df.reset_index(inplace=True)
df.rename(columns = {'index':'X',0:'y'}, inplace=True)

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib notebook
sns.set()

plt.figure(figsize = (15,8))
sns.scatterplot(x='X', y = 'y', data = df)
# Out:
# <div id='c3003878-4eaa-47db-9670-04b315942a87'></div>
