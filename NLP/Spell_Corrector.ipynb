# %% [markdown]
# <a href="https://colab.research.google.com/github/ramrajv/Upgrad_Pt_2/blob/main/NLP/Spell_Corrector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
from collections import Counter

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# function to tokenise words
def words(document):
    "Convert text to lower case and tokenise the document"
    return re.findall(r'\w+', document.lower())

# %%
# create a frequency table of all the words of the document
all_words = Counter(words(open('/content/drive/MyDrive/Upgrad/big.txt').read()))

# %%
# check frequency of a random word, say, 'chair'
all_words['chair']
# Out:
# 135

# %%
# look at top 10 frequent words
all_words.most_common(10)
# Out:
# [('the', 79809),
#  ('of', 40024),
#  ('and', 38312),
#  ('to', 28765),
#  ('in', 22023),
#  ('a', 21124),
#  ('that', 12512),
#  ('he', 12401),
#  ('was', 11410),
#  ('it', 10681)]

# %%
def edits_one(word):
    "Create all edits that are one edit away from `word`."
    alphabets    = 'abcdefghijklmnopqrstuvwxyz'
    splits     = [(word[:i], word[i:])                   for i in range(len(word) + 1)]
    deletes    = [left + right[1:]                       for left, right in splits if right]
    inserts    = [left + c + right                       for left, right in splits for c in alphabets]
    replaces   = [left + c + right[1:]                   for left, right in splits if right for c in alphabets]
    transposes = [left + right[1] + right[0] + right[2:] for left, right in splits if len(right)>1]
    return set(deletes + inserts + replaces + transposes)

# %%
len(list(edits_one('emfasize')))
# Out:
# 442

# %%
def edits_two(word):
    "Create all edits that are two edits away from `word`."
    return (e2 for e1 in edits_one(word) for e2 in edits_one(e1))

# %%
two_lst = edits_two('emfasize')
list(two_lst)
# Out:
# ['cemfaslize',
#  'emfaslize',
#  'wemfaslize',
#  'emfaseize',
#  'emfaslpze',
#  'emfaslizeg',
#  'vemfaslize',
#  'emfatslize',
#  'emfamslize',
#  'emfaslizce',
#  'evmfaslize',
#  'emfaslrize',
#  'eamfaslize',
#  'emfaolize',
#  'etfaslize',
#  'emfasliza',
#  'emfaslizf',
#  'emfalsize',
#  'efaslize',
#  'emfaslitze',
#  'emdaslize',
#  'emfaslizei',
#  'emfaslbize',
#  'eefaslize',
#  'emfaslizoe',
#  'emafslize',
#  'emfoslize',
#  'emfaslgize',
#  'emfatlize',
#  'emfaswlize',
#  'emfaslipe',
#  'emfaslqize',
#  'eyfaslize',
#  'eymfaslize',
#  'emfaslizet',
#  'emfawslize',
#  'emftslize',
#  'emfaszize',
#  'emfaslizef',
#  'emfasljze',
#  'emfasglize',
#  'emfaslije',
#  'ezfaslize',
#  'esmfaslize',
#  'emufaslize',
#  'emfasvize',
#  'emfauslize',
#  'gemfaslize',
#  'emaaslize',
#  'emfaslbze',
#  'emfaslivze',
#  'emfasloize',
#  'emfaslizeo',
#  'emdfaslize',
#  'emfaslige',
#  'emfasslize',
#  'eumfaslize',
#  'emfasulize',
#  'emfaslire',
#  'uemfaslize',
#  'emlaslize',
#  'emfpslize',
#  'qmfaslize',
#  'emfaslizee',
#  'emfablize',
#  'emfaslizs',
#  'zmfaslize',
#  'emfailize',
#  'emfaslizpe',
#  'emfahlize',
#  'remfaslize',
#  'edfaslize',
#  'emfaslizeh',
#  'emfaslixze',
#  'emmfaslize',
#  'emfaslzize',
#  'emfaselize',
#  'emvaslize',
#  'emfaslyze',
#  'emfaslile',
#  'emuaslize',
#  'eifaslize',
#  'aemfaslize',
#  'emfaslizle',
#  'ehfaslize',
#  'elfaslize',
#  'eemfaslize',
#  'emfaslirze',
#  'emvfaslize',
#  'emfasjize',
#  'emfaaslize',
#  'emfaslizw',
#  'emfaslizem',
#  'emfaslizse',
#  'emfaslizeq',
#  'emfasalize',
#  'emfasliie',
#  'qemfaslize',
#  'emfgaslize',
#  'emfaslise',
#  'emfsslize',
#  'iemfaslize',
#  'emfasxlize',
#  'emiaslize',
#  'emfaslizhe',
#  'emeaslize',
#  'emfaslizeb',
#  'emfasrlize',
#  'emfaglize',
#  'emfaslzie',
#  'emfaslhze',
#  'emjaslize',
#  'emfmaslize',
#  'emfasrize',
#  'emfasize',
#  'emfasqize',
#  'kemfaslize',
#  'emfaslizm',
#  'emfnaslize',
#  'emfaslizel',
#  'emflslize',
#  'emfaslijze',
#  'emtfaslize',
#  'emfaxlize',
#  'emfashize',
#  'emfzslize',
#  'emfaslizae',
#  'amfaslize',
#  'emcfaslize',
#  'emjfaslize',
#  'emfaslive',
#  'emfaslihe',
#  'emofaslize',
#  'temfaslize',
#  'emfacslize',
#  'emfashlize',
#  'emfasdize',
#  'emfaslpize',
#  'ecmfaslize',
#  'emfaslifze',
#  'emfajslize',
#  'egmfaslize',
#  'emfaslzze',
#  'emfqslize',
#  'emfabslize',
#  'emfdaslize',
#  'emfapslize',
#  'smfaslize',
#  'emfjaslize',
#  'emfaslizev',
#  'emfaslibze',
#  'femfaslize',
#  'emfaslizd',
#  'emfaslizv',
#  'emfasplize',
#  'emfasliye',
#  'emfaylize',
#  'emfaslizej',
#  'emfasliwze',
#  'emfsalize',
#  'bmfaslize',
#  'emfaslixe',
#  'demfaslize',
#  'emfasliyze',
#  'emzaslize',
#  'emfaslizu',
#  'emfasolize',
#  'emfcaslize',
#  'emfaslizec',
#  'emfasliee',
#  'emfaslizek',
#  'emfasblize',
#  'emfdslize',
#  'emfaclize',
#  'emfavlize',
#  'emfaxslize',
#  'eomfaslize',
#  'emfaslkze',
#  'embaslize',
#  'emfaslizze',
#  'emfaslizje',
#  'emfasilze',
#  'emfaslizeu',
#  'emfaslimze',
#  'emfagslize',
#  'emfaslizne',
#  'emfxaslize',
#  'emfaslizes',
#  'emfaslizx',
#  'emfasliz',
#  'emfaslizie',
#  'emqaslize',
#  'emfaslnze',
#  'emfaslilze',
#  'exfaslize',
#  'emfaslyize',
#  'emlfaslize',
#  'emfaslaize',
#  'emfaqlize',
#  'emfyslize',
#  'emifaslize',
#  'emfasljize',
#  'wmfaslize',
#  'emfaslizxe',
#  'emfqaslize',
#  'emfaslze',
#  'epfaslize',
#  'emgfaslize',
#  'emfasllize',
#  'emfaslie',
#  'emfbslize',
#  'mfaslize',
#  'emfasligze',
#  'emfaslizen',
#  'emfasloze',
#  'emfaslite',
#  'emfaslioze',
#  'emfasqlize',
#  'emfasclize',
#  'emfaskize',
#  'emfaslsize',
#  'emffslize',
#  'emfasklize',
#  'emafaslize',
#  'emfaslizez',
#  'emfaslfze',
#  'imfaslize',
#  'emfaelize',
#  'emfbaslize',
#  'emfascize',
#  'fmfaslize',
#  'emfastize',
#  'eqmfaslize',
#  'emfasiize',
#  'emfaslizz',
#  'emfaslizqe',
#  'emfaslizi',
#  'emfeslize',
#  'emfasltize',
#  'emfaslide',
#  'emfasfize',
#  'mmfaslize',
#  'emfasllze',
#  'emfaslizea',
#  'emfyaslize',
#  'emfaslizt',
#  'ejmfaslize',
#  'egfaslize',
#  'embfaslize',
#  'gmfaslize',
#  'dmfaslize',
#  'emfanlize',
#  'emfaplize',
#  'emfaeslize',
#  'tmfaslize',
#  'enfaslize',
#  'emfiaslize',
#  'emfasluize',
#  'emfasnize',
#  'emfaspize',
#  'emfasylize',
#  'emfafslize',
#  'emfaslizb',
#  'nmfaslize',
#  'emfaslizl',
#  'etmfaslize',
#  'emfaslizbe',
#  'emfasflize',
#  'emfaslizg',
#  'emfaslxize',
#  'emfrslize',
#  'emfvslize',
#  'emfaslizj',
#  'lmfaslize',
#  'emoaslize',
#  'emfaslsze',
#  'emfaslgze',
#  'emfaslizer',
#  'emfaslizey',
#  'emfasliuze',
#  'emgaslize',
#  'emfhaslize',
#  'emfarslize',
#  'emfaslized',
#  'hemfaslize',
#  'emfazlize',
#  'emfaslkize',
#  'ekmfaslize',
#  'emfasliae',
#  'emsfaslize',
#  'emfaslfize',
#  'edmfaslize',
#  'emfaslizn',
#  'ecfaslize',
#  'eofaslize',
#  'emfaalize',
#  'eafaslize',
#  'emfasgize',
#  'ebfaslize',
#  'kmfaslize',
#  'emfaslrze',
#  'emxfaslize',
#  'emhaslize',
#  'emfarlize',
#  'emfasjlize',
#  'rmfaslize',
#  'umfaslize',
#  'emfasxize',
#  'lemfaslize',
#  'efmfaslize',
#  'emfxslize',
#  'ebmfaslize',
#  'emfaslime',
#  'emftaslize',
#  'emmaslize',
#  'emfalslize',
#  'emfaslidze',
#  'memfaslize',
#  'emfaslibe',
#  'emfasliue',
#  'emfazslize',
#  'erfaslize',
#  'emfasliwe',
#  'exmfaslize',
#  'emfaslipze',
#  'emfaslioe',
#  'ezmfaslize',
#  'emfasvlize',
#  'emfaslhize',
#  'emfadlize',
#  'emnaslize',
#  'emfgslize',
#  'emfaslizk',
#  'emfaslizme',
#  'emfasline',
#  'emfaslcize',
#  'ewfaslize',
#  'emfaszlize',
#  'bemfaslize',
#  'emfaklize',
#  'emhfaslize',
#  'emfasoize',
#  'enmfaslize',
#  'emfwaslize',
#  'emfsaslize',
#  'emfasyize',
#  'effaslize',
#  'emfaflize',
#  'emfuaslize',
#  'nemfaslize',
#  'emfkslize',
#  'empaslize',
#  'emfcslize',
#  'emfaslizc',
#  'emfasuize',
#  'emfaslizde',
#  'emfavslize',
#  'emfaslisze',
#  'emyaslize',
#  'emfasliqze',
#  'emfwslize',
#  'jemfaslize',
#  'ermfaslize',
#  'emfaslwize',
#  'emfaslizo',
#  'esfaslize',
#  'emfasleize',
#  'emfasliez',
#  'ejfaslize',
#  'ekfaslize',
#  'yemfaslize',
#  'emfaslvze',
#  'oemfaslize',
#  'emfhslize',
#  'emfasldze',
#  'emrfaslize',
#  'epmfaslize',
#  'emfaslizr',
#  'emfislize',
#  'emzfaslize',
#  'emfaslice',
#  'emflaslize',
#  'emfahslize',
#  'emfasaize',
#  'emraslize',
#  'emfasltze',
#  'jmfaslize',
#  'emfaslizke',
#  'emfvaslize',
#  'emfasbize',
#  'emfaslnize',
#  'emfmslize',
#  'emfoaslize',
#  'emfaslizue',
#  'mefaslize',
#  'emfaislize',
#  'emnfaslize',
#  'emkfaslize',
#  'emfanslize',
#  'emfakslize',
#  'emfslize',
#  'emfaslinze',
#  'emaslize',
#  'emfaslmize',
#  'emfzaslize',
#  'emffaslize',
#  'ewmfaslize',
#  'xemfaslize',
#  'emfaslizh',
#  'emfasleze',
#  'emfaslqze',
#  'emfaqslize',
#  'emfraslize',
#  'emfastlize',
#  'emfaslizre',
#  'emfasliqe',
#  'emfaslwze',
#  'emfasnlize',
#  'evfaslize',
#  'emfaslizq',
#  'pemfaslize',
#  'emsaslize',
#  'emfaslcze',
#  'emfaslizwe',
#  'emtaslize',
#  'emefaslize',
#  'emfasliaze',
#  'emfaslaze',
#  'emfalize',
#  'emfasmlize',
#  'emqfaslize',
#  'emfaswize',
#  'zemfaslize',
#  'ymfaslize',
#  'emkaslize',
#  'omfaslize',
#  'emcaslize',
#  'emfallize',
#  'empfaslize',
#  'emfasluze',
#  'emfaslife',
#  'emfaoslize',
#  'emfaslizfe',
#  'emyfaslize',
#  'emfaslizte',
#  'emfasliize',
#  'emfuslize',
#  'emfaslizp',
#  'pmfaslize',
#  'emfasmize',
#  'emfaslizye',
#  'eufaslize',
#  'emfaslmze',
#  'emfaslihze',
#  'eqfaslize',
#  'emfaulize',
#  'emfaslvize',
#  'emfaslizex',
#  'emfaslicze',
#  'emfaslike',
#  'emfaslikze',
#  'emfasilize',
#  'emfaslizep',
#  'emfkaslize',
#  'xmfaslize',
#  'emfaslxze',
#  'emfpaslize',
#  'elmfaslize',
#  'emxaslize',
#  'emfjslize',
#  'emfajlize',
#  'eimfaslize',
#  'emfaslizve',
#  'emfaslieze',
#  'emwfaslize',
#  'emfeaslize',
#  'semfaslize',
#  'emfadslize',
#  'emfassize',
#  'emfasdlize',
#  'emfnslize',
#  'emfasldize',
#  'ehmfaslize',
#  'emfawlize',
#  'vmfaslize',
#  'emfayslize',
#  'efmaslize',
#  'emwaslize',
#  'emfaslizew',
#  'emfaslizge',
#  'emfamlize',
#  'hmfaslize',
#  'emfaslizy',
#  'cmfaslize',
#  'emfaslize',
#  'emfaseizf',
#  'gemfaseize',
#  'emfaseize',
#  'emwaseize',
#  'temfaseize',
#  'demfaseize',
#  'emfaseioze',
#  'emgaseize',
#  'emfaseioe',
#  'emfaseifze',
#  'emfaseizer',
#  'emfiaseize',
#  'jemfaseize',
#  'emrfaseize',
#  'emfqseize',
#  'emfaheize',
#  'emfayseize',
#  'wmfaseize',
#  'emfaseizfe',
#  'emfaseiee',
#  'emfaserze',
#  'emfnaseize',
#  'embaseize',
#  'lemfaseize',
#  'emnfaseize',
#  'emfasjeize',
#  'emfaseizej',
#  'emfaseizc',
#  'emfaszize',
#  'emfaseizef',
#  'emfaseizes',
#  'emfaseizey',
#  'emfakeize',
#  'bemfaseize',
#  'emfasevze',
#  'lmfaseize',
#  'emfaseizee',
#  'emfasoeize',
#  'emfaseiz',
#  'emfaseizxe',
#  'emfdseize',
#  'emfasvize',
#  'emfaseiwe',
#  'empfaseize',
#  'emfasevize',
#  'emfaseizen',
#  'emfcseize',
#  'emnaseize',
#  'amfaseize',
#  'ecmfaseize',
#  'emfaseuize',
#  'emfageize',
#  'emfasenize',
#  'emfaseiwze',
#  'emfanseize',
#  'emcfaseize',
#  'emffaseize',
#  'emfaseizeo',
#  'emfasedize',
#  'emfpseize',
#  'ymfaseize',
#  'emfaselize',
#  'eomfaseize',
#  'ehmfaseize',
#  'emfaseizm',
#  'emifaseize',
#  'emfaserize',
#  'tmfaseize',
#  'emfaseinze',
#  'emmaseize',
#  'emfasjize',
#  'emfasreize',
#  'emfaseizie',
#  'emfaseizae',
#  'emfasenze',
#  'epfaseize',
#  'emxaseize',
#  'ewmfaseize',
#  'yemfaseize',
#  'xmfaseize',
#  'eamfaseize',
#  'emfasfeize',
#  'emfaseizeb',
#  'emhfaseize',
#  'remfaseize',
#  'emfaseicze',
#  'emfaseizy',
#  'emfasseize',
#  'emfaseizev',
#  'emfaeeize',
#  'emfaseizhe',
#  'evfaseize',
#  'emqfaseize',
#  'emfasebize',
#  'emfasrize',
#  'emfasize',
#  'emfaseizv',
#  'emfasqize',
#  'emfaseizeq',
#  'emfasefze',
#  'emfaseizec',
#  'qmfaseize',
#  'ewfaseize',
#  'emfashize',
#  'egmfaseize',
#  'emfasbeize',
#  'emfaseigze',
#  'smfaseize',
#  'emfaseire',
#  'mmfaseize',
#  'emfasegze',
#  'emvaseize',
#  'emfaseoze',
#  'emfasyeize',
#  'oemfaseize',
#  'emfasdize',
#  'emfaseijze',
#  'emfasieize',
#  'emfaseizp',
#  'emwfaseize',
#  'emfavseize',
#  'emfasewize',
#  'emkaseize',
#  'emfaieize',
#  'emfaseiaze',
#  'vmfaseize',
#  'emfaseyze',
#  'emyfaseize',
#  'emfaseipze',
#  'emvfaseize',
#  'emxfaseize',
#  'emfajeize',
#  'emlfaseize',
#  'emafaseize',
#  'emfaiseize',
#  'egfaseize',
#  'emfaseibe',
#  'emfaseized',
#  'emfaseqze',
#  'emfaeize',
#  'wemfaseize',
#  'emfarseize',
#  'emefaseize',
#  'ejfaseize',
#  'emfaqeize',
#  'emfnseize',
#  'umfaseize',
#  'ebmfaseize',
#  'eqmfaseize',
#  'emfiseize',
#  'emfabseize',
#  'emfasehize',
#  'emfaseiyze',
#  'emfaseeize',
#  'emfvseize',
#  'emfdaseize',
#  'emfazseize',
#  'emffseize',
#  'emfaseizez',
#  'emfwseize',
#  'emqaseize',
#  'emfasesze',
#  'emfazeize',
#  'emfaleize',
#  'emfaesize',
#  'emfaneize',
#  'emfuaseize',
#  'emfaseizve',
#  'emfasqeize',
#  'emfaseqize',
#  'emlaseize',
#  'emmfaseize',
#  'emfyseize',
#  'emoaseize',
#  'effaseize',
#  'emhaseize',
#  'emfaseizq',
#  'emsfaseize',
#  'emfpaseize',
#  'pmfaseize',
#  'emfaseizue',
#  'emfaseizel',
#  'emfasegize',
#  'emfajseize',
#  'xemfaseize',
#  'ecfaseize',
#  'etmfaseize',
#  'emfaqseize',
#  'emfaseizu',
#  'emfaseipe',
#  'cmfaseize',
#  'esmfaseize',
#  'emfagseize',
#  'emfasewze',
#  'emfaceize',
#  'emfaseine',
#  'emfasueize',
#  'emfmaseize',
#  'emfaseizn',
#  'emfaskize',
#  'emfaseide',
#  'emfasneize',
#  'emcaseize',
#  'emfuseize',
#  'emfaseieze',
#  'omfaseize',
#  'emfaseaze',
#  'emkfaseize',
#  'emsaseize',
#  'eumfaseize',
#  'emfeseize',
#  'emfyaseize',
#  'emfaseice',
#  'emfaseze',
#  'emfzseize',
#  'emfascize',
#  'emaseize',
#  'emfasceize',
#  'emfaseoize',
#  'emfaseizge',
#  'emfaseizje',
#  'emfastize',
#  'emaaseize',
#  'emfabeize',
#  'emfasiize',
#  'emfaseizt',
#  'emfaseizce',
#  'evmfaseize',
#  'emfaseizre',
#  'emfaszeize',
#  'ermfaseize',
#  'emfasfize',
#  'emfasefize',
#  'edmfaseize',
#  'emfoaseize',
#  'aemfaseize',
#  'emfaseuze',
#  'emfaseizl',
#  'emfaseizeu',
#  'emfaseizw',
#  'emfsaseize',
#  'emfasepize',
#  'emfaseite',
#  'emfhseize',
#  'emfaseizs',
#  'efmfaseize',
#  'emfaseizte',
#  'emfoseize',
#  'emfaseiqze',
#  'gmfaseize',
#  'ezmfaseize',
#  'efaseize',
#  'ekmfaseize',
#  'emfasheize',
#  'emdaseize',
#  'emfasekze',
#  'emfaseihe',
#  'emfasnize',
#  'emfgaseize',
#  'emfaspize',
#  'emfbseize',
#  'emfasaeize',
#  'emfeaseize',
#  'emfaseizeg',
#  'emfaseizet',
#  'emfsaeize',
#  'hmfaseize',
#  'semfaseize',
#  'emfaseizew',
#  'emofaseize',
#  'emfasweize',
#  'emfqaseize',
#  'emfaseiez',
#  'emfkseize',
#  'emfaseive',
#  'emfaseixe',
#  'jmfaseize',
#  'emfaseiue',
#  'enmfaseize',
#  'emfaskeize',
#  'emfaseile',
#  'emfxaseize',
#  'emfasgize',
#  'zmfaseize',
#  'edfaseize',
#  'emfaaseize',
#  'emfasezze',
#  'emfaseyize',
#  'zemfaseize',
#  'emfraseize',
#  'emfaseivze',
#  'emfaseizem',
#  'eefaseize',
#  'emfamseize',
#  'emftseize',
#  'emfasxize',
#  'emfzaseize',
#  'eufaseize',
#  'emzaseize',
#  'emfaseeze',
#  'emfmseize',
#  'kemfaseize',
#  'eqfaseize',
#  'emfaseizoe',
#  'ebfaseize',
#  'emfjseize',
#  'mefaseize',
#  'emfaxeize',
#  'erfaseize',
#  'emfadeize',
#  'emftaseize',
#  'ekfaseize',
#  'emfaseizg',
#  'emfaseiye',
#  'uemfaseize',
#  'hemfaseize',
#  'emgfaseize',
#  'emfsseize',
#  'eafaseize',
#  'bmfaseize',
#  'emfafeize',
#  'emfaseizde',
#  'emfateize',
#  'femfaseize',
#  'emfafseize',
#  'emfasdeize',
#  'emfaseiae',
#  'emfhaseize',
#  'emfseize',
#  'emfasteize',
#  'emfasesize',
#  'emfasoize',
#  'emfasyize',
#  'emfaveize',
#  'emfasmeize',
#  'eimfaseize',
#  'nmfaseize',
#  'emfaaeize',
#  'emfkaseize',
#  'emfaseidze',
#  'emfaseimze',
#  'eofaseize',
#  'eemfaseize',
#  'emfaxseize',
#  'emfaseizne',
#  'emfaseige',
#  'enfaseize',
#  'emfasuize',
#  'emfakseize',
#  'emfaseilze',
#  'emfaseirze',
#  'eifaseize',
#  'emfasepze',
#  'emfaseife',
#  'emfgseize',
#  'emfaseizze',
#  'emfaseizea',
#  'emfaueize',
#  'emfatseize',
#  'emfaseise',
#  'emfasleize',
#  'eyfaseize',
#  'emfaseizx',
#  'emfasgeize',
#  'emfaseizek',
#  'emfapseize',
#  'emfaseizb',
#  'emfaseizk',
#  'emfaseizex',
#  'emfaseizd',
#  'emuaseize',
#  'emfaseikze',
#  'emfalseize',
#  'emfasecze',
#  'emdfaseize',
#  'emfaseizz',
#  'emfasxeize',
#  'emfjaseize',
#  'emfaseime',
#  'emfapeize',
#  'emfasaize',
#  'emfasemze',
#  'emfaseizke',
#  'emfaoseize',
#  'emfasbize',
#  'emfaseizr',
#  'emfahseize',
#  'emfaseitze',
#  'ezfaseize',
#  'emfaseizse',
#  'emfwaseize',
#  'emfaseije',
#  'emfasezie',
#  'emfasejize',
#  'emjaseize',
#  'emyaseize',
#  'emzfaseize',
#  'dmfaseize',
#  'emfaseiize',
#  'emflaseize',
#  'kmfaseize',
#  'imfaseize',
#  'emfaseihze',
#  'emfaseizqe',
#  'emfaseizeh',
#  'emfxseize',
#  'emfaseizwe',
#  'iemfaseize',
#  'emfaseie',
#  'epmfaseize',
#  'emfaspeize',
#  'emfaseizye',
#  'qemfaseize',
#  'emfaweize',
#  'emfaselze',
#  'emfaoeize',
#  'emfaseizj',
#  'emfvaseize',
#  'nemfaseize',
#  'cemfaseize',
#  'ehfaseize',
#  'emfasekize',
#  'emraseize',
#  'elmfaseize',
#  'elfaseize',
#  'pemfaseize',
#  'emafseize',
#  'emfasetze',
#  'esfaseize',
#  'rmfaseize',
#  'emfaseizle',
#  'emjfaseize',
#  'emfaseizpe',
#  'emfaswize',
#  'emfasemize',
#  'emfameize',
#  'eymfaseize',
#  'emfayeize',
#  'emfaseiie',
#  'ejmfaseize',
#  'emfaseizei',
#  'emfaseizo',
#  'emtfaseize',
#  'etfaseize',
#  'emfasezize',
#  'exfaseize',
#  'emfadseize',
#  'emtaseize',
#  'emfbaseize',
#  'emfasedze',
#  'emfasehze',
#  'emfaeseize',
#  'exmfaseize',
#  'vemfaseize',
#  'emfawseize',
#  'emfasmize',
#  'emfasexze',
#  'mfaseize',
#  'emflseize',
#  'emfaseizh',
#  'emfaseiuze',
#  'embfaseize',
#  'emfasetize',
#  'emfasejze',
#  'emfaseiza',
#  'emfasveize',
#  'efmaseize',
#  'emeaseize',
#  'emfasieze',
#  'emfauseize',
#  'emfaseizme',
#  'emufaseize',
#  'emfaseizi',
#  'emfareize',
#  'emfaseibze',
#  'emfaseike',
#  'emfasexize',
#  'emfaseixze',
#  'emfasebze',
#  'emfassize',
#  'emfasecize',
#  'fmfaseize',
#  'emfaseizbe',
#  'memfaseize',
#  'emfaseisze',
#  'emfaseizep',
#  'emfaseiqe',
#  'emfaseaize',
#  'emfrseize',
#  'emfcaseize',
#  'empaseize',
#  'emfacseize',
#  'emiaseize',
#  'emxfrasize',
#  'egmxfasize',
#  'nemxfasize',
#  'emxfasize',
#  'emxfasipze',
#  'emyxfasize',
#  'emnxfasize',
#  'emifasize',
#  'emxfqsize',
#  'emxfasime',
#  'emxfasizxe',
#  'emofasize',
#  ...]

# %%
len(list(edits_two('emfasize')))
# Out:
# 206656

# %%
def known(words):
    "The subset of `words` that appear in the `all_words`."
    return set(word for word in words if word in all_words)

# %%
def possible_corrections(word):
    "Generate possible spelling corrections for word."
    return (known([word]) or known(edits_one(word)) or known(edits_two(word)) or [word])

# %%
len(list(possible_corrections('emfasize')))
# Out:
# 1

# %%
def prob(word, N=sum(all_words.values())): 
    "Probability of `word`: Number of appearances of 'word' / total number of tokens"
    return all_words[word] / N

# %%
print(len(set(edits_one("monney"))))
print(edits_one("monney"))
# Out:
# 336
# {'qmonney', 'mknney', 'monny', 'conney', 'emonney', 'moniey', 'mornney', 'lonney', 'mconney', 'momnney', 'monoey', 'monneyg', 'monneyd', 'mqonney', 'monjey', 'ionney', 'mkonney', 'monneyl', 'monneys', 'monkney', 'monneyr', 'moxney', 'mocney', 'monnet', 'monnemy', 'monneky', 'monnen', 'dmonney', 'monneb', 'mooney', 'monneuy', 'monpney', 'monneoy', 'moneny', 'monneg', 'monnexy', 'mvonney', 'monndey', 'konney', 'mobney', 'moinney', 'monyney', 'monnef', 'manney', 'mbnney', 'monneyu', 'movnney', 'moiney', 'mxonney', 'minney', 'monnsy', 'mcnney', 'monnsey', 'mgonney', 'monnqy', 'onney', 'moxnney', 'molney', 'moaney', 'mwnney', 'mondney', 'monsey', 'monbney', 'monneyz', 'monnel', 'moqney', 'meonney', 'monqney', 'monvney', 'moonney', 'hmonney', 'moznney', 'monnev', 'monngy', 'mqnney', 'mozney', 'monfney', 'mognney', 'monne', 'mdnney', 'monnek', 'mogney', 'moneney', 'monnby', 'tonney', 'mounney', 'gonney', 'omnney', 'monyey', 'monnem', 'mobnney', 'monnwey', 'monneby', 'monnevy', 'mionney', 'monxney', 'amonney', 'monnay', 'tmonney', 'monnfy', 'monnepy', 'monnkey', 'moynney', 'monnyey', 'aonney', 'monngey', 'yonney', 'monnyy', 'monneyp', 'ymonney', 'honney', 'mocnney', 'monnjey', 'monneyn', 'mosney', 'monneh', 'jonney', 'monaney', 'monneay', 'motnney', 'monnejy', 'monneq', 'mmnney', 'mvnney', 'monbey', 'monncey', 'monmey', 'monned', 'monnrey', 'monnvy', 'monnney', 'monneyb', 'monnhy', 'nonney', 'moncey', 'msonney', 'monmney', 'mzonney', 'maonney', 'fmonney', 'mfonney', 'mouney', 'monnehy', 'monnpey', 'monnewy', 'monnesy', 'monnxy', 'monnes', 'fonney', 'morney', 'mnney', 'monneiy', 'monnecy', 'mowney', 'mpnney', 'mofney', 'monnfey', 'mronney', 'mbonney', 'monnezy', 'monwney', 'monkey', 'monnjy', 'monneny', 'monney', 'wonney', 'munney', 'zonney', 'movney', 'mznney', 'monnny', 'myonney', 'mojnney', 'nmonney', 'monzney', 'imonney', 'mdonney', 'moknney', 'moenney', 'monneyq', 'monvey', 'monniy', 'monneye', 'mononey', 'moyney', 'monqey', 'muonney', 'mwonney', 'monlney', 'monnep', 'sonney', 'monnley', 'monjney', 'cmonney', 'monnefy', 'kmonney', 'monneyh', 'monnee', 'modney', 'monnedy', 'monnej', 'mfnney', 'monneqy', 'mojney', 'monuney', 'monneyx', 'monfey', 'mmonney', 'mhnney', 'xonney', 'mrnney', 'moneey', 'mopney', 'monsney', 'monndy', 'smonney', 'monneyv', 'monnzey', 'motney', 'monnly', 'msnney', 'monneyf', 'monnbey', 'monneyy', 'monley', 'monnmey', 'monhey', 'monrney', 'uonney', 'vonney', 'moqnney', 'moanney', 'monxey', 'mponney', 'monuey', 'mlonney', 'mtnney', 'monnry', 'monnery', 'monneyw', 'monzey', 'mjnney', 'montey', 'montney', 'mofnney', 'bmonney', 'monnky', 'mohney', 'wmonney', 'mongey', 'lmonney', 'mjonney', 'mnnney', 'monnety', 'omonney', 'moniney', 'monnty', 'monwey', 'monnwy', 'monnew', 'moeney', 'monhney', 'monneu', 'mynney', 'monneo', 'monncy', 'monrey', 'modnney', 'monneyo', 'mokney', 'monniey', 'vmonney', 'monneyj', 'mnonney', 'menney', 'ronney', 'mhonney', 'eonney', 'mlnney', 'jmonney', 'monnea', 'xmonney', 'mopnney', 'pmonney', 'zmonney', 'monneyi', 'donney', 'mtonney', 'monnez', 'mosnney', 'mongney', 'monnmy', 'oonney', 'monnxey', 'umonney', 'mownney', 'momney', 'mohnney', 'monnuey', 'monnegy', 'monnye', 'monnhey', 'mondey', 'monneya', 'bonney', 'monnec', 'molnney', 'mxnney', 'monntey', 'monnaey', 'gmonney', 'money', 'monnoey', 'monnvey', 'monneyk', 'monneey', 'monneyc', 'ponney', 'mgnney', 'monpey', 'moncney', 'monnely', 'monnoy', 'monnzy', 'monaey', 'rmonney', 'qonney', 'monnei', 'monner', 'monnuy', 'monneyt', 'monnex', 'mnoney', 'monneym', 'monnqey', 'monnpy'}

# %%
print(known(edits_one("monney")))
# Out:
# {'money', 'monkey'}

# %%
# Let's look at words that are two edits away
print(len(set(edits_two("monney"))))
print(known(edits_one("monney")))
# Out:
# 51013
# {'money', 'monkey'}

# %%
# Let's look at possible corrections of a word
print(possible_corrections("monney"))
# Out:
# {'money', 'monkey'}

# %%
# Let's look at probability of a word
print(prob("money"))
print(prob("monkey"))
# Out:
# 0.0002922233626303688
# 5.378344097491451e-06

# %%
def spell_check(word):
    "Print the most probable spelling correction for `word` out of all the `possible_corrections`"
    correct_word = max(possible_corrections(word), key=prob)
    if correct_word != word:
        return "Did you mean " + correct_word + "?"
    else:
        return "Correct spelling."

# %%
# test spell check
print(spell_check("monney"))
# Out:
# Did you mean money?
